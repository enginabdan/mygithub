# %%
import pandas as pd
import shopify
import requests
import json

# %%
url = "https://gzdgf:drgzggz@sgggr.dzgzg.com/admin/api/2023-01/products.json?limit=250"
#data_prd = requests.get(url_prd)

# %%
#url = "https://dfgszgzsdgz.com"

# %%
def get_json(url, page):
    """
    Get Shopify products.json from a store URL.
    Args:
        url (str): URL of the store.
        page (int): Page number of the products.json.
    Returns:
        products_json: Products.json from the store.
    """

    try:
        response = requests.get(f'{url}/products.json?limit=250&page={page}', timeout=5)
        products_json = response.text
        response.raise_for_status()
        return products_json

    except requests.exceptions.HTTPError as error_http:
        print("HTTP Error:", error_http)

    except requests.exceptions.ConnectionError as error_connection:
        print("Connection Error:", error_connection)

    except requests.exceptions.Timeout as error_timeout:
        print("Timeout Error:", error_timeout)

    except requests.exceptions.RequestException as error:
        print("Error: ", error)

# %%
products_json = get_json(url, 1)

# %%
def to_df(products_json):
    """
    Convert products.json to a pandas DataFrame.
    Args:
        products_json (json): Products.json from the store.
    Returns:
        df: Pandas DataFrame of the products.json.
    """

    try:
        products_dict = json.loads(products_json)
        df = pd.DataFrame.from_dict(products_dict['products'])
        return df
    except Exception as e:
        print(e)

# %%
df = to_df(products_json)
df
# Out:
#                 id                                              title  \
# 0    8182478110949                                TV825 TV STAND (FW)
# 1    8161927561445                          Lupino Orange Velvet Sofa
# 2    8161933623525                      Lupino Orange Velvet Loveseat
# 3    8182429745381                                     ERNST TV STAND
# 4    8182409101541                       Montego Nesting Table Walnut
# ..             ...                                                ...
# 245  8171131371749  Penelope 4-piece Eastern King Bedroom Set Midn...
# 246  8170649321701                        Elegance Ormen V42 loveseat
# 247  8170648830181                    Elegance Ormen V42 accent chair
# 248  8170648174821                            Elegance Ormen V42 sofa
# 249  8170380919013                                 Papatya Side Table
#
#                                                 handle  \
# 0                                    tv825-tv-stand-fw
# 1                            lupino-orange-velvet-sofa
# 2                        lupino-orange-velvet-loveseat
# 3                                       ernst-tv-stand
# 4                       montego-nesting-table-walnut-1
# ..                                                 ...
# 245  penelope-4-piece-eastern-king-bedroom-set-midn...
# 246                        elegance-ormen-v42-loveseat
# 247                    elegance-ormen-v42-accent-chair
# 248                            elegance-ormen-v42-sofa
# 249                                 papatya-side-table
#
#                                              body_html  \
# 0                                  TV825 TV STAND (FW)
# 1    <p data-mce-fragment="1"><span data-mce-fragme...
# 2    <p data-mce-fragment="1"><span data-mce-fragme...
# 3    <h1 data-mce-fragment="1">PRODUCT DIMENSION</h...
# 4                  <p>Montego Nesting Table Walnut</p>
# ..                                                 ...
# 245  Penelope 2-drawer nightstand black : 17.00"D x...
# 246  <p>One of the best and most effective options ...
# 247  <p>One of the best and most effective options ...
# 248  <p>One of the best and most effective options ...
# 249                          <p>Papatya Side Table</p>
#
#                   published_at                 created_at  \
# 0    2023-01-14T19:16:39-05:00  2023-01-14T19:16:38-05:00
# 1    2023-01-14T17:53:53-05:00  2022-12-23T12:33:42-05:00
# 2    2023-01-14T17:53:32-05:00  2022-12-23T12:36:34-05:00
# 3    2023-01-14T16:59:17-05:00  2023-01-14T16:59:16-05:00
# 4    2023-01-14T15:14:20-05:00  2023-01-14T15:14:20-05:00
# ..                         ...                        ...
# 245  2023-01-02T19:30:04-05:00  2023-01-02T19:30:02-05:00
# 246  2023-01-01T17:38:47-05:00  2023-01-01T17:38:03-05:00
# 247  2023-01-01T17:35:30-05:00  2023-01-01T17:35:30-05:00
# 248  2023-01-01T17:33:57-05:00  2023-01-01T17:33:55-05:00
# 249  2022-12-31T19:51:40-05:00  2022-12-31T19:51:39-05:00
#
#                     updated_at             vendor product_type  \
# 0    2023-01-14T19:18:55-05:00  Win Win Furniture
# 1    2023-01-14T17:53:58-05:00               Nova         Sofa
# 2    2023-01-14T17:53:36-05:00               Nova     Loveseat
# 3    2023-01-14T17:11:02-05:00  Win Win Furniture
# 4    2023-01-14T15:14:25-05:00            Bellona
# ..                         ...                ...          ...
# 245  2023-01-14T20:03:14-05:00            Coaster
# 246  2023-01-14T20:20:52-05:00  Win Win Furniture
# 247  2023-01-14T20:20:52-05:00  Win Win Furniture
# 248  2023-01-14T20:20:52-05:00  Win Win Furniture
# 249  2023-01-14T17:53:02-05:00            New Art
#
#                                                   tags  \
# 0                                                   []
# 1    [3000-3500, Availability_In Stock, color_orang...
# 2    [3000-3500, Availability_In Stock, color_orang...
# 3                                                   []
# 4                                           [500-1000]
# ..                                                 ...
# 245                                                 []
# 246                                                 []
# 247                                                 []
# 248                                                 []
# 249                                       [side-table]
#
#                                               variants  \
# 0    [{'id': 43831203496165, 'title': 'Default Titl...
# 1    [{'id': 43786226106597, 'title': 'Default Titl...
# 2    [{'id': 43786234200293, 'title': 'Default Titl...
# 3    [{'id': 43831067082981, 'title': 'Default Titl...
# 4    [{'id': 43830993551589, 'title': 'Default Titl...
# ..                                                 ...
# 245  [{'id': 43804993650917, 'title': 'Default Titl...
# 246  [{'id': 43803402272997, 'title': 'Default Titl...
# 247  [{'id': 43803401158885, 'title': 'Default Titl...
# 248  [{'id': 43803400536293, 'title': 'Default Titl...
# 249  [{'id': 43802684784869, 'title': 'Default Titl...
#
#                                                 images  \
# 0                                                   []
# 1    [{'id': 39246691565797, 'created_at': '2022-12...
# 2    [{'id': 39246721810661, 'created_at': '2022-12...
# 3                                                   []
# 4                                                   []
# ..                                                 ...
# 245  [{'id': 39335929774309, 'created_at': '2023-01...
# 246  [{'id': 39335974109413, 'created_at': '2023-01...
# 247  [{'id': 39335981252837, 'created_at': '2023-01...
# 248  [{'id': 39335952777445, 'created_at': '2023-01...
# 249                                                 []
#
#                                                options
# 0    [{'name': 'Title', 'position': 1, 'values': ['...
# 1    [{'name': 'Title', 'position': 1, 'values': ['...
# 2    [{'name': 'Title', 'position': 1, 'values': ['...
# 3    [{'name': 'Title', 'position': 1, 'values': ['...
# 4    [{'name': 'Title', 'position': 1, 'values': ['...
# ..                                                 ...
# 245  [{'name': 'Title', 'position': 1, 'values': ['...
# 246  [{'name': 'Title', 'position': 1, 'values': ['...
# 247  [{'name': 'Title', 'position': 1, 'values': ['...
# 248  [{'name': 'Title', 'position': 1, 'values': ['...
# 249  [{'name': 'Title', 'position': 1, 'values': ['...
#
# [250 rows x 13 columns]

# %%
def get_products(url):
    """
    Get all products from a store.
    Returns:
        df: Pandas DataFrame of the products.json.
    """

    results = True
    page = 1
    df = pd.DataFrame()

    while results:
        products_json = get_json(url, page)
        products_dict = to_df(products_json)

        if len(products_dict) == 0:
            break
        else:
            df = pd.concat([df, products_dict], ignore_index=True)
            page += 1

    df['url'] = f"{url}/products/" + df['handle']
    return df

# %%
products = get_products(url)

# %%
products.shape
# Out:
# (5484, 14)

# %%
products.columns
# Out:
# Index(['id', 'title', 'handle', 'body_html', 'published_at', 'created_at',
#        'updated_at', 'vendor', 'product_type', 'tags', 'variants', 'images',
#        'options', 'url'],
#       dtype='object')

# %%
products.head(2)
# Out:
#               id                      title                     handle  \
# 0  8182478110949        TV825 TV STAND (FW)          tv825-tv-stand-fw
# 1  8161927561445  Lupino Orange Velvet Sofa  lupino-orange-velvet-sofa
#
#                                            body_html  \
# 0                                TV825 TV STAND (FW)
# 1  <p data-mce-fragment="1"><span data-mce-fragme...
#
#                 published_at                 created_at  \
# 0  2023-01-14T19:16:39-05:00  2023-01-14T19:16:38-05:00
# 1  2023-01-14T17:53:53-05:00  2022-12-23T12:33:42-05:00
#
#                   updated_at             vendor product_type  \
# 0  2023-01-14T19:18:55-05:00  Win Win Furniture
# 1  2023-01-14T17:53:58-05:00               Nova         Sofa
#
#                                                 tags  \
# 0                                                 []
# 1  [3000-3500, Availability_In Stock, color_orang...
#
#                                             variants  \
# 0  [{'id': 43831203496165, 'title': 'Default Titl...
# 1  [{'id': 43786226106597, 'title': 'Default Titl...
#
#                                               images  \
# 0                                                 []
# 1  [{'id': 39246691565797, 'created_at': '2022-12...
#
#                                              options  \
# 0  [{'name': 'Title', 'position': 1, 'values': ['...
# 1  [{'name': 'Title', 'position': 1, 'values': ['...
#
#                                                  url
# 0  https://winwinfurn.com/products/tv825-tv-stand-fw
# 1  https://winwinfurn.com/products/lupino-orange-...
