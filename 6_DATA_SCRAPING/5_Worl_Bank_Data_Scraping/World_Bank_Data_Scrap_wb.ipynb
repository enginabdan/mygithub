# %% [markdown]
# ### Installation

# %%
# pip install world-bank-data
# pip install world_bank_data --upgrade
# https://pypi.org/project/world-bank-data/ (All the thing are here)
# https://data.worldbank.org/products/third-party-apps (Third Party Apps)

# %% [markdown]
# ### topics, sources, countries, regions, incomelevels, lendingtypes, indicators, search, language

# %%
# import pandas as pd
# import world_bank_data as wb
# pd.set_option('display.max_rows', 6)
# wb.get_topics()
# wb.get_sources()
# wb.get_countries()
# wb.get_regions()
# wb.get_incomelevels
# wb.get_lendingtypes()
# wb.get_indicators()
# wb.search_countries()
# wb.get_series('SP.POP.TOTL', date='2016', id_or_value='id', simplify_index=True)
# wb.options.language = "en"

# %%
import pandas as pd
import world_bank_data as wb
pd.set_option('display.max_rows', 25)

# %%
wb.get_topics()
# Out:
#                               value  \
# id
# 1   Agriculture & Rural Development
# 2                 Aid Effectiveness
# 3                  Economy & Growth
# 4                         Education
# 5                   Energy & Mining
# 6                       Environment
# 7                  Financial Sector
# 8                            Health
# 9                    Infrastructure
# 10        Social Protection & Labor
# 11                          Poverty
# 12                   Private Sector
# 13                    Public Sector
# 14             Science & Technology
# 15               Social Development
# 16                Urban Development
# 17                           Gender
# 18      Millenium development goals
# 19                   Climate Change
# 20                    External Debt
# 21                            Trade
#
#                                            sourceNote
# id
# 1   For the 70 percent of the world's poor who liv...
# ...

# %%
wb.get_sources()
# Out:
#    lastupdated                                           name code  \
# id
# 1   2021-08-18                                 Doing Business  DBS
# 2   2022-07-20                   World Development Indicators  WDI
# 3   2021-09-27                Worldwide Governance Indicators  WGI
# 5   2016-03-21              Subnational Malnutrition Database  SNM
# 6   2022-01-14                  International Debt Statistics  IDS
# ..         ...                                            ...  ...
# 84  2022-07-19                               Education Policy  EDP
# 85  2022-07-06                                  PEFA_2021_SNG  SNG
# 86  2021-09-24         Global Jobs Indicators Database (JOIN)  JON
# 87  2022-06-10  Country Climate and Development Report (CCDR)  CCD
# 88  2022-07-05                      Food Prices for Nutrition  FPN
#
#    description url dataavailability metadataavailability concepts
# id
# 1                                 Y                    Y        3
# ...

# %%
wb.get_countries()
# Out:
#     iso2Code                                               name  \
# id
# ABW       AW                                              Aruba
# AFE       ZH                        Africa Eastern and Southern
# AFG       AF                                        Afghanistan
# AFR       A9                                             Africa
# AFW       ZI                         Africa Western and Central
# ..       ...                                                ...
# XZN       A5  Sub-Saharan Africa excluding South Africa and ...
# YEM       YE                                        Yemen, Rep.
# ZAF       ZA                                       South Africa
# ZMB       ZM                                             Zambia
# ZWE       ZW                                           Zimbabwe
#
#                          region  \
# id
# ABW  Latin America & Caribbean
# AFE                  Aggregates
# AFG                  South Asia
# AFR                  Aggregates
# ...

# %%
wb.get_regions()
# Out:
#    code iso2code                                               name
# id
#     AFE       ZH                        Africa Eastern and Southern
#     AFR       A9                                             Africa
#     AFW       ZI                         Africa Western and Central
#     ARB       1A                                         Arab World
#     CAA       C9            Sub-Saharan Africa (IFC classification)
# ..  ...      ...                                                ...
# 9   SSF       ZG                                Sub-Saharan Africa
#     SST       S1                                       Small states
#     SXZ       A4          Sub-Saharan Africa excluding South Africa
#     WLD       1W                                              World
#     XZN       A5  Sub-Saharan Africa excluding South Africa and ...
#
# [44 rows x 3 columns]

# %%
wb.get_incomelevels()
# Out:
#     iso2code                value
# id
# HIC       XD          High income
# INX       XY       Not classified
# LIC       XM           Low income
# LMC       XN  Lower middle income
# LMY       XO  Low & middle income
# MIC       XP        Middle income
# UMC       XT  Upper middle income

# %%
wb.get_lendingtypes()
# Out:
#     iso2code           value
# id
# IBD       XF            IBRD
# IDB       XH           Blend
# IDX       XI             IDA
# LNX       XX  Not classified

# %%
wb.get_indicators()
# Out:
#                                                                    name unit  \
# id
# 1.0.HCount.1.90usd                      Poverty Headcount ($1.90 a day)
# 1.0.HCount.2.5usd                       Poverty Headcount ($2.50 a day)
# 1.0.HCount.Mid10to50              Middle Class ($10-50 a day) Headcount
# 1.0.HCount.Ofcl                 Official Moderate Poverty Rate-National
# 1.0.HCount.Poor4uds                        Poverty Headcount ($4 a day)
# ...                                                                 ...  ...
# WP15163_4.3                          Mobile account, female (% age 15+)
# WP15163_4.8            Mobile account, income, poorest 40% (% ages 15+)
# WP15163_4.9            Mobile account, income, richest 60% (% ages 15+)
# wpremia_F             Wage Premia for Females (the ratio of skilled ...
# wpremia_M             Wage Premia for Males  (the ratio of skilled m...
#
#                                                           source  \
# id
# ...

# %%
wb.get_indicators(topic=3, source=2)
# topic and source id are from get_topics/get_sources
# Out:
#                                                                 name unit  \
# id
# BG.GSR.NFSV.GD.ZS                       Trade in services (% of GDP)
# BM.GSR.CMCP.ZS     Communications, computer, etc. (% of service i...
# BM.GSR.FCTY.CD            Primary income payments (BoP, current US$)
# BM.GSR.GNFS.CD      Imports of goods and services (BoP, current US$)
# BM.GSR.INSF.ZS     Insurance and financial services (% of service...
# ...                                                              ...  ...
# NY.TTF.GNFS.KN              Terms of trade adjustment (constant LCU)
# PA.NUS.ATLS          DEC alternative conversion factor (LCU per US$)
# PA.NUS.PPP         PPP conversion factor, GDP (LCU per internatio...
# PA.NUS.PPPC.RF     Price level ratio of PPP conversion factor (GD...
# PA.NUS.PRVT.PP     PPP conversion factor, private consumption (LC...
#
#                                          source  \
# id
# BG.GSR.NFSV.GD.ZS  World Development Indicators
# ...

# %%
wb.search_indicators('mathematics')
# wb.search_countries('mathematics')
# wb.search_source('mathematics')
# Out:
#                                                                          name  \
# id
# 2.0.cov.Math.pl_2.all               Coverage: Mathematics Proficiency Level 2
# 2.0.cov.Math.pl_2.prv       Coverage: Mathematics Proficiency Level 2, Pri...
# 2.0.cov.Math.pl_2.pub       Coverage: Mathematics Proficiency Level 2, Pub...
# 2.0.cov.Math.pl_3.all               Coverage: Mathematics Proficiency Level 3
# 2.0.cov.Math.pl_3.prv       Coverage: Mathematics Proficiency Level 3, Pri...
# ...                                                                       ...
# UIS.MATH.PRIMARY.NONNATIVE  Proportion of students at the end of primary e...
# UIS.MATH.PRIMARY.NPIA       Proportion of students at the end of primary e...
# UIS.MATH.PRIMARY.RURAL      Proportion of students at the end of primary e...
# UIS.MATH.PRIMARY.URBAN      Proportion of students at the end of primary e...
# UIS.MATH.PRIMARY.WPIA       Proportion of students at the end of primary a...
#
# ...

# %%
# wb.get_series('SP.POP.TOTL', mrv=1)
    # The result above has a 3-dimensional index.
    # Use the argument simplify_index
    # to ignore the dimensions that take a single value (here: year and series).
    # Also, use the argument id_or_value='id'
    # if you prefer your data to be indexed by the codes rather than labels:
# wb.get_series('SP.POP.TOTL', date='2016', id_or_value='id', simplify_index=True)
    # mrv, integer: one or more most recent values
    # date, string: either one year, or two years separated with a colon, like '2010:2018'
    # gapfill, string: 'Y' or 'N' (the default): forward fills missing values.

# %%
# Country and indicator description in non-English languages
wb.options.language = 'en'
wb.get_indicators('SP.POP.TOTL')
# Out:
#                           name unit                        source  \
# id
# SP.POP.TOTL  Population, total       World Development Indicators
#
#                                                     sourceNote  \
# id
# SP.POP.TOTL  Total population is based on the de facto defi...
#
#                                             sourceOrganization  \
# id
# SP.POP.TOTL  (1) United Nations Population Division. World ...
#
#                              topics
# id
# SP.POP.TOTL  Climate Change,Health

# %%
wb.get_series('SP.POP.TOTL', date='2010:2020', id_or_value='id', simplify_index=True)
# Out:
# Country  Year
# AFE      2010    518468229.0
#          2011    532760424.0
#          2012    547482863.0
#          2013    562601578.0
#          2014    578075373.0
#                     ...
# ZWE      2016     14030338.0
#          2017     14236599.0
#          2018     14438812.0
#          2019     14645473.0
#          2020     14862927.0
# Name: SP.POP.TOTL, Length: 2926, dtype: float64

# %%
wb.get_series('SP.POP.TOTL', date='2010:2020', id_or_value='id', simplify_index=True)
# Out:
# Country  Year
# AFE      2010    518468229.0
#          2011    532760424.0
#          2012    547482863.0
#          2013    562601578.0
#          2014    578075373.0
#                     ...
# ZWE      2016     14030338.0
#          2017     14236599.0
#          2018     14438812.0
#          2019     14645473.0
#          2020     14862927.0
# Name: SP.POP.TOTL, Length: 2926, dtype: float64

# %%
wb.get_topics()
# Out:
#                               value  \
# id
# 1   Agriculture & Rural Development
# 2                 Aid Effectiveness
# 3                  Economy & Growth
# 4                         Education
# 5                   Energy & Mining
# 6                       Environment
# 7                  Financial Sector
# 8                            Health
# 9                    Infrastructure
# 10        Social Protection & Labor
# 11                          Poverty
# 12                   Private Sector
# 13                    Public Sector
# 14             Science & Technology
# 15               Social Development
# 16                Urban Development
# 17                           Gender
# 18      Millenium development goals
# 19                   Climate Change
# 20                    External Debt
# 21                            Trade
#
#                                            sourceNote
# id
# 1   For the 70 percent of the world's poor who liv...
# ...

# %%
wb.get_sources()
# Out:
#    lastupdated                                           name code  \
# id
# 1   2021-08-18                                 Doing Business  DBS
# 2   2022-07-20                   World Development Indicators  WDI
# 3   2021-09-27                Worldwide Governance Indicators  WGI
# 5   2016-03-21              Subnational Malnutrition Database  SNM
# 6   2022-01-14                  International Debt Statistics  IDS
# ..         ...                                            ...  ...
# 84  2022-07-19                               Education Policy  EDP
# 85  2022-07-06                                  PEFA_2021_SNG  SNG
# 86  2021-09-24         Global Jobs Indicators Database (JOIN)  JON
# 87  2022-06-10  Country Climate and Development Report (CCDR)  CCD
# 88  2022-07-05                      Food Prices for Nutrition  FPN
#
#    description url dataavailability metadataavailability concepts
# id
# 1                                 Y                    Y        3
# ...

# %%
wb.get_indicators(topic=13)
# Out:
#                                                                 name unit  \
# id
# GB.TAX.CMAR.ZS         Highest marginal tax rate, corporate rate (%)
# GC.AST.TOTL.CN     Net acquisition of financial assets (current LCU)
# GC.AST.TOTL.GD.ZS     Net acquisition of financial assets (% of GDP)
# GC.DOD.TOTL.CN          Central government debt, total (current LCU)
# GC.DOD.TOTL.GD.ZS          Central government debt, total (% of GDP)
# ...                                                              ...  ...
# VC.IDP.TOTL.LE     Internally displaced persons (number, low esti...
# VC.IHR.PSRC.FE.P5  Intentional homicides, female (per 100,000 fem...
# VC.IHR.PSRC.MA.P5     Intentional homicides, male (per 100,000 male)
# VC.IHR.PSRC.P5            Intentional homicides (per 100,000 people)
# VC.PKP.TOTL.UN     Presence of peace keepers (number of troops, p...
#
#                                           source  \
# id
# GB.TAX.CMAR.ZS     Africa Development Indicators
# ...

# %%
df = wb.get_series(indicator="GC.AST.TOTL.GD.ZS",
                   date="2002:2021",
                   country="TUR",
                   id_or_value="id",
                   simplify_index=True)
df
# Out:
# Year
# 2002         NaN
# 2003         NaN
# 2004         NaN
# 2005         NaN
# 2006         NaN
# 2007         NaN
# 2008    0.328401
# 2009    0.722857
# 2010   -0.315933
# 2011    1.011686
# 2012    0.896024
# 2013    0.910673
# 2014    1.079747
# 2015    1.595065
# 2016    0.995298
# 2017    0.893686
# 2018    0.870535
# 2019    2.109354
# 2020    4.275715
# 2021         NaN
# Name: GC.AST.TOTL.GD.ZS, dtype: float64

# %%
wb.search_countries("TUR")
# Out:
#     iso2Code                      name                      region  \
# id
# TCA       TC  Turks and Caicos Islands  Latin America & Caribbean
# TKM       TM              Turkmenistan       Europe & Central Asia
# TUR       TR                   Turkiye       Europe & Central Asia
#
#                                        adminregion          incomeLevel  \
# id
# TCA                                                         High income
# TKM  Europe & Central Asia (excluding high income)  Upper middle income
# TUR  Europe & Central Asia (excluding high income)  Upper middle income
#
#         lendingType capitalCity  longitude   latitude
# id
# TCA  Not classified  Grand Turk -71.141389  21.460278
# TKM            IBRD    Ashgabat  58.379400  37.950900
# TUR            IBRD      Ankara  32.360600  39.715300
